# %%
import time
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats
from scipy.integrate import odeint
import scipy.odr
import scipy
import statistics as st
import math
from matplotlib.pylab import *
from tabulate import tabulate

# %%
b_0 = [4.648e+03, 1.181e+02, -3.238e-02]
b_25 = [2.789e+06, 1.170e+02, -2.177e-02]
b_50 = [1.726e+06, 1.191e+02, -2.391e-02]
b_1 = [1.132e+06, 1.192e+02, -2.422e-02]
b_2 = [3.196e+06, 1.275e+02, -3.593e-02]
b_0_100 = [1.080e-07, 1.455e+00, 1.075e-01]
b_25_75 = [4.423e+00, 8.591e+01, -7.909e-04]
b_50_50 = [9.960e+00, 8.949e+01, -4.601e-03]
b_75_25 = [4.026e+04, 1.260e+02, -3.387e-02]
b_100_0 = [5.327e+04, 1.282e+02, -3.847e-02]

samplenames = ['TiO$_2$', '0.25 wt% Ni/TiO$_2$', '0.5 wt% Ni/TiO$_2$', '1 wt% Ni/TiO$_2$', '2 wt% Ni/TiO$_2$', 
               '0/100', '25/75', '50/50', '75/25', '100/0']

third_elements = [b_0[2], b_25[2], b_50[2], b_1[2], b_2[2], 
                  b_0_100[2], b_25_75[2], b_50_50[2], b_75_25[2], b_100_0[2]]

plt.figure(figsize=(10, 6))
plt.plot(samplenames, third_elements, marker='o', markersize = 9, linestyle='None', color='darkseagreen')
plt.xlabel('Samples', fontsize=16)
plt.ylabel('k$_d$', fontsize=16)
#plt.title('Deactivation', fontsize=16)
plt.xticks(rotation=45, ha='right', fontsize=14)
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
b_0 = [4.648e+03, 1.181e+02, -3.238e-02]
b_25 = [2.789e+06, 1.170e+02, -2.177e-02]
b_50 = [1.726e+06, 1.191e+02, -2.391e-02]
b_1 = [1.132e+06, 1.192e+02, -2.422e-02]
b_2 = [3.196e+06, 1.275e+02, -3.593e-02]
#b_0_100 = [1.080e-07, 1.455e+00, 1.075e-01]
b_25_75 = [4.423e+00, 8.591e+01, -7.909e-04]
b_50_50 = [9.960e+00, 8.949e+01, -4.601e-03]
b_75_25 = [4.026e+04, 1.260e+02, -3.387e-02]
b_100_0 = [5.327e+04, 1.282e+02, -3.847e-02]

samplenames = ['TiO$_2$', '0.25 wt% Ni/TiO$_2$', '0.5 wt% Ni/TiO$_2$', '1 wt% Ni/TiO$_2$', '2 wt% Ni/TiO$_2$', 
               '25/75', '50/50', '75/25', '100/0']

third_elements = [b_0[2], b_25[2], b_50[2], b_1[2], b_2[2], 
                   b_25_75[2], b_50_50[2], b_75_25[2], b_100_0[2]]

plt.figure(figsize=(10, 6))
plt.plot(samplenames, third_elements, marker='o', markersize = 9, linestyle='None', color='darkseagreen')
plt.xlabel('Samples', fontsize=16)
plt.ylabel('Deactivation, k$_d$', fontsize=16)
#plt.title('Deactivation', fontsize=16)
plt.xticks(rotation=45, ha='right', fontsize=14)
plt.grid(True)
plt.tight_layout()
plt.show()
